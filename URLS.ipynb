# %%
# SPORTS
URL_Sports=[]
# URL SPORTS AND SUBLISTS
URLl_blog = []
URLl_football = []
URLl_Hockey=[]
URLl_Basket=[]
URLl_PSL=[]
URLl_IPL=[]
URLl_BPL=[]
URLl_ICC=[]
URLl_Baseball=[]
URLl_Tennis=[]

# URLS FOR BLOG CRICKET [SPORTS]
URL  = "https://cricketpakistan.com.pk/en/blogs/detail/ramiz-raja-needs-to-carefully-handle-pressure-of-expectations"
URL1 = "https://cricketpakistan.com.pk/en/blogs/detail/asif-ali-haris-rauf-prove-misbahul-haq-right"
URL2 = "http://womens-cricket.blogspot.com/2021/10/tough-weekend-in-wbbl07.html"
URL3 = "https://sports.ndtv.com/cricket/ball-tampering-scandal-steve-smith-not-a-hero-but-he-isnt-a-villain-either-1828918"
URL4 = "https://sports.ndtv.com/cricket/why-it-s-time-to-respect-indian-cricket-umpires-and-hail-their-efforts-1499792"
URLl_blog.append(URL)
URLl_blog.append(URL1)
URLl_blog.append(URL2)
URLl_blog.append(URL3)
URLl_blog.append(URL4)

# URLS FOR FOOTBALL [SPORTS]
f_URL1 = "https://footballblog.co.uk/premier-league-matchday-25-saturday-preview-predictions/"
f_URL2 = "https://www.skysports.com/football/news/11781/12549627/leon-balogun-says-borussia-dortmund-are-weakened-by-erling-haalands-absence-for-europa-league-second-leg-with-rangers"
f_URL3 = "https://www.footballpakistan.com/2022/02/adils-story-of-perseverance-express-tribune/"
f_URL4 = "https://www.the-aiff.com/article/indian-footballers-take-a-stand-of-zero-tolerance-for-female-genital-mutilation"
f_URL5 = "https://www.checkfit.co.uk/introduction-to-football/"
URLl_football.append(f_URL1)
URLl_football.append(f_URL2)
URLl_football.append(f_URL3)
URLl_football.append(f_URL4)
URLl_football.append(f_URL5)

# URLS FOR HOCKEY [SPORTS]
h_URL1  = "https://recreation.dartmouth.edu/intramurals/rules/ice-hockey-rules"
h_URL2  = "https://en.wikipedia.org/wiki/Pakistan_Hockey_Federation"
h_URL3  = "https://www.hockeyindia.org/news/hockey-india-name-20-member-indian-mens-hockey-team-for-fih-pro-league-matches-against-spain"
h_URL4  = "http://www.fih.ch/events/world-cup/womens-world-cup-2022/news/path-to-2022-fih-hockey-womens-world-cup-glory-laid-out/"
h_URL5  = "https://www.hockeywrldnws.com/great-britain-beat-resurgent-india-to-bronze/"
URLl_Hockey.append(h_URL1)
URLl_Hockey.append(h_URL2)
URLl_Hockey.append(h_URL3)
URLl_Hockey.append(h_URL4)
URLl_Hockey.append(h_URL5)

# URLS FOR BASKETBALL [SPORTS]
bas_URL1 = "https://www.betterhealth.vic.gov.au/health/healthyliving/basketball-health-benefits#health-benefits-of-basketball"
bas_URL2 = "https://www.britannica.com/sports/basketball"
bas_URL3 = "https://www.rulesofsport.com/sports/basketball.html"
bas_URL4 = "https://www.masterclass.com/articles/basketball-rules-explained#what-are-the-rules-of-basketball"
bas_URL5 = "https://coach.basketball.net.au/the-power-of-imitation/"
URLl_Basket.append(bas_URL1)
URLl_Basket.append(bas_URL2)
URLl_Basket.append(bas_URL3)
URLl_Basket.append(bas_URL4)
URLl_Basket.append(bas_URL5)

# URLS FOR PSL [SPORTS]
psl_URL1 = "https://theshoppies.pk/cricket-fever-of-psl-2020/"
psl_URL2 = "https://cricketpakistan.com.pk/en/news/detail/rashid-khan-ready-to-play-for-qalandars-even-in-the-lowest-category"
psl_URL3 = "https://theweeklysports.com/list-of-centuries-in-hbl-psl-centuries-scored-in-pakistan-super-league/"
psl_URL4 = "https://www.crictracker.com/most-runs-in-psl-highest-run-scorer-in-psl-history/"
psl_URL5 = "https://grassrootscricket.pk/blog/detail/psl-2022-lahore-qalandars-preview"
URLl_PSL.append(psl_URL1)
URLl_PSL.append(psl_URL2)
URLl_PSL.append(psl_URL3)
URLl_PSL.append(psl_URL4)
URLl_PSL.append(psl_URL5)

# URLS FOR IPL [SPORTS]
ipl_URL1 = "https://crickettimes.com/2022/02/pakistan-pacer-shahnawaz-dahani-recalls-meeting-with-legendary-ms-dhoni-terms-it-as-dream-come-true-moment/"
ipl_URL2= "https://cricketaddictor.com/indian-premier-league-ipl-2022/ipl-2022-groups-announced-csk-and-mi-divided-into-2-separate-groups/"
ipl_URL3= "https://www.iplt20.com/matches/results/men/2021"
ipl_URL4 = "https://www.iplt20.com/matches/results/men/2021"
ipl_URL5= "https://sports.ndtv.com/cricket/sunrisers-hyderabad-congratulate-david-warner-on-ashes-victory-wish-him-luck-for-ipl-mega-auction-2676281"
URLl_IPL.append(ipl_URL1)
URLl_IPL.append(ipl_URL2)
URLl_IPL.append(ipl_URL3)
URLl_IPL.append(ipl_URL4)
URLl_IPL.append(ipl_URL5)

# URLS FOR BPL [SPORTS]
bpl_URL1 = "https://en.wikipedia.org/wiki/Bangladesh_Premier_League"
bpl_URL2 = "https://wisden.com/stories/global-t20-leagues/bangladesh-premier-league-2022/bpl-2022-full-squad-and-team-list-injury-replacement-updates-of-bangladesh-premier-league-t20"
bpl_URL3 = "https://et20slam.net/bpl-all-teams-squad/"
bpl_URL4  = "https://www.espncricinfo.com/series/bangladesh-premier-league-2021-22-1296684/squads"
bpl_URL5 = "https://t20slam.com/bpl-players-price-franchise-owners-sponsors/"
URLl_BPL.append(bpl_URL1)
URLl_BPL.append(bpl_URL2)
URLl_BPL.append(bpl_URL3)
URLl_BPL.append(bpl_URL4)
URLl_BPL.append(bpl_URL5)

# URLS FOR ICC [SPORTS]
icc_URL1 = "https://www.icc-cricket.com/media-releases/2505266"
icc_URL2 = "https://www.icc-cpi.int/about"
icc_URL3 = "https://en.wikipedia.org/wiki/International_Cricket_Council"
icc_URL4 = "https://www.cricketworldcup.com/news/2503903"
icc_URL5 = "https://www.icc-cricket.com/media-releases/2354895"
URLl_ICC.append(icc_URL1)
URLl_ICC.append(icc_URL2)
URLl_ICC.append(icc_URL3)
URLl_ICC.append(icc_URL4)
URLl_ICC.append(icc_URL5)

# URLS FOR Baseball [SPORTS]
base_URL1 = "https://www.britannica.com/sports/baseball"
base_URL2= "https://www.rulesofsport.com/sports/baseball.html"
base_URL3= "https://baseballhall.org/discover/baseball-history/athletics-of-1927-fielded-roster-filled-with-future-hall-of-famers"
base_URL4 = "https://www.mlbtraderumors.com/"
base_URL5 = "https://baseballhall.org/baseball-history-american-history-and-you"
URLl_Baseball.append(base_URL1)
URLl_Baseball.append(base_URL2)
URLl_Baseball.append(base_URL3)
URLl_Baseball.append(base_URL4)
URLl_Baseball.append(base_URL5)

# URLS FOR Tennis [SPORTS]
ten_URL1 = "https://www.britannica.com/sports/tennis#ref29701"
ten_URL2 = "http://protennistips.net/tennis-rules/"
ten_URL3 = "https://www.lovetennisblog.com/flowlife-flowgun-go-massage-gun-review/"
ten_URL4  = "https://womenstennisblog.com/2022/02/26/ukraine-war-tennis-players/"
ten_URL5  = "https://howtheyplay.com/individual-sports/Top-10-Greatest-Female-Tennis-Players-of-All-Time"
URLl_Tennis.append(ten_URL1)
URLl_Tennis.append(ten_URL2)
URLl_Tennis.append(ten_URL3)
URLl_Tennis.append(ten_URL4)
URLl_Tennis.append(ten_URL5)

# APPENDING ALL SPORTS URLs TO ONE LIST
URL_Sports.append(URLl_Basket)
URL_Sports.append(URLl_football)
URL_Sports.append(URLl_blog)
URL_Sports.append(URLl_Hockey)
URL_Sports.append(URLl_PSL)
URL_Sports.append(URLl_IPL)
URL_Sports.append(URLl_BPL)
URL_Sports.append(URLl_ICC)
URL_Sports.append(URLl_Baseball)
URL_Sports.append(URLl_Tennis)

# CURRENT AFFAIRS
URL_CurrentAffairs=[]
# URL CURRENT AFFAIRS AND SUBLISTS
URLl_unemp = []
URLl_hunger = []
URLl_dom_violence=[]
URLl_child_labour=[]
URLl_illetracy=[]
URLl_feminism=[]
URLl_Islampohobia=[]
URLl_Curroption=[]
URLl_costliness=[]
URLl_dishonesty=[]

# URLS FOR UNEMPLOYMENT [CURRENT AFFAIRS]
unemp_URL1 = "https://www.managementstudyguide.com/what-is-employment.htm"
unemp_URL2 = "https://www.investopedia.com/financial-edge/0811/the-cost-of-unemployment-to-the-economy.aspx"
unemp_URL3 = "https://www.investopedia.com/articles/economics/10/unemployment-rate-get-real.asp"
unemp_URL4  = "https://www.imf.org/external/pubs/ft/fandd/basics/32-unemployment.htm"
unemp_URL5  = "https://www.managementstudyguide.com/what-is-unemployment.htm"
URLl_unemp.append(unemp_URL1)
URLl_unemp.append(unemp_URL2)
URLl_unemp.append(unemp_URL3)
URLl_unemp.append(unemp_URL4)
URLl_unemp.append(unemp_URL5)

# URLS FOR HUNGER [CURRENT AFFAIRS]
hunger_URL1 = "https://www.actionagainsthunger.org/global-poverty-hunger-facts"
hunger_URL2 = "https://thp.org/what-we-do/issues/poverty/"
hunger_URL3 = "https://www.bread.org/what-causes-hunger"
hunger_URL4  = "https://www.tandfonline.com/doi/full/10.1080/1331677X.2019.1583588"
hunger_URL5 = "https://www.welthungerhilfe.org/hunger/"
URLl_hunger.append(hunger_URL1)
URLl_hunger.append(hunger_URL2)
URLl_hunger.append(hunger_URL3)
URLl_hunger.append(hunger_URL4)
URLl_hunger.append(hunger_URL5)

# URLS FOR DOMESTIC VIOLENCE [CURRENT AFFAIRS]
domv_URL1 = "https://www.wadvocates.org/2020/05/26/loss-of-agency-how-domestic-violence-impacts-mental-health/"
domv_URL2 = "https://www.theline.org.au/7-types-of-violence-you-need-to-know-about/"
domv_URL3 = "https://jpma.org.pk/article-details/1042?article_id=1042"
domv_URL4  = "https://aamft.org/Consumer_Updates/Domestic_Violence.aspx"
domv_URL5 = "https://www.verywellmind.com/different-types-of-domestic-violence-5119884"
URLl_dom_violence.append(domv_URL1)
URLl_dom_violence.append(domv_URL2)
URLl_dom_violence.append(domv_URL3)
URLl_dom_violence.append(domv_URL4)
URLl_dom_violence.append(domv_URL5)

# URLS FOR CHILD LABOUR [CURRENT AFFAIRS]
chlab_URL1 = "https://ec.europa.eu/international-partnerships/stories/child-labour-keeping-millions-children-out-school_en"
chlab_URL2 = "https://www.britannica.com/topic/child-labour"
chlab_URL3 = "https://www.childfund.org.au/stories/how-child-labour-affects-children-around-the-world/"
chlab_URL4  = "https://www.eclt.org/en/news/child-labour-causes"
chlab_URL5 = "https://www.studytoday.net/child-labour/"
URLl_child_labour.append(chlab_URL1)
URLl_child_labour.append(chlab_URL2)
URLl_child_labour.append(chlab_URL3)
URLl_child_labour.append(chlab_URL4)
URLl_child_labour.append(chlab_URL5)

# URLS FOR ILLITERACY [CURRENT AFFAIRS]
ill_URL1 = "https://worldliteracyfoundation.org/early-intervention-reduces-illiteracy/"
ill_URL2  = r"https://indianexpresss.in/illiteracy-meaning-causes-effects-consequences-and-solutions/#:~:text=Illiteracy%20is%20a%20state%20whereby,challenges%20in%20reading%20and%20writing."
ill_URL3  = "https://imp.center/i/short-paragraph-illiteracy-4132/"
ill_URL4   = "https://canvas.fau.edu/eportfolios/2192/Home/3_Major_Causes_of_Illiteracy_in_Pakistan"
ill_URL5  = "https://www.thoughtco.com/what-is-illiteracy-1691146"
URLl_illetracy.append(ill_URL1)
URLl_illetracy.append(ill_URL2)
URLl_illetracy.append(ill_URL3)
URLl_illetracy.append(ill_URL4)
URLl_illetracy.append(ill_URL5)

# URLS FOR FEMINISM [CURRENT AFFAIRS]
fem_URL1 = "https://www.britannica.com/topic/feminism"
fem_URL2  = "https://www.empowerwomen.org/en/community/discussions/2016/11/the-importance-of-feminism-for-men-and-women"
fem_URL3  = r"https://www.pewresearch.org/fact-tank/2020/07/07/61-of-u-s-women-say-feminist-describes-them-well-many-see-feminism-as-empowering-polarizing/#:~:text=But%20the%20public%20has%20mixed,critical%20of%20the%20feminist%20movement."
fem_URL4   = "https://revisesociology.com/2017/02/03/feminist-theory-summary-sociology/"
fem_URL5  = "https://environmental-conscience.com/feminism-pros-cons/"
URLl_feminism.append(fem_URL1)
URLl_feminism.append(fem_URL2)
URLl_feminism.append(fem_URL3)
URLl_feminism.append(fem_URL4)
URLl_feminism.append(fem_URL5)

# URLS FOR CURRPOTION [CURRENT AFFAIRS]
isl_URL1 = "https://www.ucpress.edu/blog/31415/islamophobia-close-home/"
isl_URL2  = "https://news.gallup.com/poll/157082/islamophobia-understanding-anti-muslim-sentiment-west.aspx"
isl_URL3  = "https://www.sv.uio.no/c-rex/english/groups/compendium/what-is-islamophobia.html"
isl_URL4   = "https://www.dailysabah.com/op-ed/2018/04/06/impact-of-islamophobia-on-cultures-and-global-politics"
isl_URL5  = "https://www.ucpress.edu/blog/46688/islamophobia-is-a-global-phenomenon/"
URLl_Islampohobia.append(isl_URL1)
URLl_Islampohobia.append(isl_URL2)
URLl_Islampohobia.append(isl_URL3)
URLl_Islampohobia.append(isl_URL4)
URLl_Islampohobia.append(isl_URL5)

# URLS FOR Islampohobia [CURRENT AFFAIRS]
cur_URL1 = "https://www.transparency.org/en/what-is-corruption"
cur_URL2  = "https://www.intechopen.com/chapters/58969"
cur_URL3  = "https://www.transparency.org/en/news/how-to-stop-corruption-5-key-ingredients"
cur_URL4   = "https://borgenproject.org/10-facts-about-corruption-in-pakistan/"
cur_URL5  = "https://en.wikipedia.org/wiki/Corruption_in_Pakistan"
URLl_Curroption.append(cur_URL1)
URLl_Curroption.append(cur_URL2)
URLl_Curroption.append(cur_URL3)
URLl_Curroption.append(cur_URL4)
URLl_Curroption.append(cur_URL5)

# URLS FOR COSTLINESS [CURRENT AFFAIRS]
cost_URL1 = "https://www.investopedia.com/terms/c/cost-of-living.asp"
cost_URL2  = "http://ahsankhaneco.blogspot.com/2012/04/inflation-in-pakistan-its-types-causes.html"
cost_URL3  = r"https://www.thebalance.com/inflation-impact-on-economy-3306102#:~:text=Over%20time%2C%20inflation%20increases%20your,enough%2C%20it%20hurts%20the%20economy.&text=Rising%20prices%20may%20be%20an,demand%20for%20goods%20and%20services."
cost_URL4   = "https://tribune.com.pk/story/2297924/why-govts-cannot-control-inflation"
cost_URL5  = r"https://dailytimes.com.pk/324808/pti-government-needs-to-control-inflation-in-pakistan/#:~:text=Inflation%20can%20be%20control%20by,in%20volume%20of%20savings%20etc."
URLl_costliness.append(cost_URL1)
URLl_costliness.append(cost_URL2)
URLl_costliness.append(cost_URL3)
URLl_costliness.append(cost_URL4)
URLl_costliness.append(cost_URL5)

# URLS FOR DISHONESTY [CURRENT AFFAIRS]
dish_URL1 = "https://smallbusiness.chron.com/causes-dishonesty-workplace-13568.html"
dish_URL2 = "https://www.labourguide.co.za/discipline-dismissal/267-dishonesty-is-a-thorny-issue-to-tackle"
dish_URL3  = "https://www.teamgantt.com/blog/four-ways-that-dishonesty-is-holding-you-back-in-business"
dish_URL4  = "https://www.indeed.com/career-advice/career-development/dealing-with-dishonesty-in-the-workplace"
dish_URL5 = "https://www.emcins.com/losscontrol/insights-d/2018/11/dishonest-employees/"
URLl_dishonesty.append(dish_URL1)
URLl_dishonesty.append(dish_URL2)
URLl_dishonesty.append(dish_URL3)
URLl_dishonesty.append(dish_URL4)
URLl_dishonesty.append(dish_URL5)

# APPENDING ALL CURRENT AFFAIRS URLs TO ONE LIST
URL_CurrentAffairs.append(URLl_unemp)
URL_CurrentAffairs.append(URLl_hunger)
URL_CurrentAffairs.append(URLl_dom_violence)
URL_CurrentAffairs.append(URLl_child_labour)
URL_CurrentAffairs.append(URLl_illetracy)
URL_CurrentAffairs.append(URLl_feminism)
URL_CurrentAffairs.append(URLl_Islampohobia)
URL_CurrentAffairs.append(URLl_Curroption)
URL_CurrentAffairs.append(URLl_costliness)
URL_CurrentAffairs.append(URLl_dishonesty)

# CULTURE_RELIGION
URL_CultReligion=[]
# URL CULTURE AND RELIGION AND SUBLISTS
URLl_Islam= []
URLl_chris = []
URLl_Hinduism=[]
URLl_Judaism=[]
URLl_festivals=[]
URLl_sikhism=[]
URLl_pak=[]
URLl_india=[]


# URLS FOR ISLAM [CULTURE AND RELIGION]
Isl_URL1 = "https://www.mymasjid.ca/beginners-guide-understanding-islam/chapter-1"
Isl_URL2 = "https://www.mymasjid.ca/beginners-guide-understanding-islam/chapter-2"
Isl_URL3  = "https://www.mymasjid.ca/beginners-guide-understanding-islam/chapter-4"
Isl_URL4  = "https://www.mymasjid.ca/beginners-guide-understanding-islam/chapter-5"
Isl_URL5 = r"https://www.history.com/topics/religion/islam#:~:text=Mosques%20are%20places%20where%20Muslims,major%20holy%20text%20of%20Islam."
URLl_Islam.append(Isl_URL1)
URLl_Islam.append(Isl_URL2)
URLl_Islam.append(Isl_URL3)
URLl_Islam.append(Isl_URL4)
URLl_Islam.append(Isl_URL5)

# URLS FOR CHRISTIANITY [CULTURE AND RELIGION]
chris_URL1 = "https://www.britannica.com/topic/Christianity"
chris_URL2 = "https://www.worldhistory.org/christianity/"
chris_URL3  = "https://symbolsage.com/different-types-of-christianity/"
chris_URL4  = "https://www.crossway.org/articles/21-key-christian-figures-you-should-know/"
chris_URL5 =  "https://christianhistoryinstitute.org/magazine/article/how-we-christians-worship"
URLl_chris.append(chris_URL1)
URLl_chris.append(chris_URL2)
URLl_chris.append(chris_URL3)
URLl_chris.append(chris_URL4)
URLl_chris.append(chris_URL5)

# URLS FOR HINDUISM [CULTURE AND RELIGION]
hind_URL1 = "https://www.gettysburg.edu/offices/religious-spiritual-life/world-religions-101/what-is-hinduism"
hind_URL2 = "https://www.history.com/topics/religion/hinduism#section_1"
hind_URL3  = "https://www.setfreealliance.org/indian-caste-system-explained/#"
hind_URL4  = "https://www.blueosa.com/10-hindu-deities-everyone-know-pilgrimage-india/"
hind_URL5 =  "https://www.history.com/topics/religion/hinduism#section_9"
URLl_Hinduism.append(hind_URL1)
URLl_Hinduism.append(hind_URL2)
URLl_Hinduism.append(hind_URL3)
URLl_Hinduism.append(hind_URL4)
URLl_Hinduism.append(hind_URL5)

# URLS FOR JUDAISM [CULTURE AND RELIGION]
jud_URL1 = "https://www.history.com/topics/religion/judaism#section_1"
jud_URL2 = "https://www.khanacademy.org/humanities/ap-art-history/introduction-cultures-religions-apah/judaism-apah/a/judaism-an-introduction"
jud_URL3  = "https://www.bbc.co.uk/religion/religions/judaism/beliefs/beliefs_1.shtml"
jud_URL4  = "https://www.britannica.com/topic/Hebrew-Bible"
jud_URL5 =  "https://www.britannica.com/topic/synagogue"
URLl_Judaism.append(jud_URL1)
URLl_Judaism.append(jud_URL2)
URLl_Judaism.append(jud_URL3)
URLl_Judaism.append(jud_URL4)
URLl_Judaism.append(jud_URL5)

# URLS FOR FESTIVALS [CULTURE AND RELIGION]
fest_URL1 = "https://www.halalzilla.com/islamic-festivals-mark-calendars/90179"
fest_URL2 = "https://theculturetrip.com/asia/india/articles/10-hindu-festivals-you-should-know-about/"
fest_URL3  = "https://www.bolton.ac.uk/Chaplaincy/Worldviews/Festivals/ChristianFestivals.aspx#gsc.tab=0"
fest_URL4  = "https://www.britannica.com/topic/Jewish-festivals"
fest_URL5 =  "https://www.learnreligions.com/sikh-holidays-and-festivals-2992994"
URLl_festivals.append(fest_URL1)
URLl_festivals.append(fest_URL2)
URLl_festivals.append(fest_URL3)
URLl_festivals.append(fest_URL4)
URLl_festivals.append(fest_URL5)

# URLS FOR SIKHISM [CULTURE AND RELIGION]
sikh_URL1 = "https://theconversation.com/who-are-the-sikhs-and-what-are-their-beliefs-97237"
sikh_URL2 = "https://www.bbc.co.uk/religion/religions/sikhism/customs/fiveks.shtml"
sikh_URL3  = "https://www.bbc.co.uk/religion/religions/sikhism/ritesrituals/gurdwara_1.shtml"
sikh_URL4  = "https://www.sikhdharma.org/sikh-history/ten-sikh-gurus/"
sikh_URL5 =  "https://canadiansikhheritage.ca/sikh-figures/"
URLl_sikhism.append(sikh_URL1)
URLl_sikhism.append(sikh_URL2)
URLl_sikhism.append(sikh_URL3)
URLl_sikhism.append(sikh_URL4)
URLl_sikhism.append(sikh_URL5)

# URLS FOR PAK CULTURE [CULTURE AND RELIGION]
pak_URL1 = "https://theculturetrip.com/asia/pakistan/articles/13-things-you-should-know-about-pakistani-culture/"
pak_URL2 = "https://historypak.com/punjabi-culture/"
pak_URL3  = "https://historypak.com/sindhi-culture/"
pak_URL4  = r"https://historypak.com/balochi-culture/#:~:text=Baloch%20culture%20is%20opposite%20to,are%20done%20by%20the%20females."
pak_URL5 =  "https://www.britannica.com/place/Khyber-Pakhtunkhwa"
pak_URL6 =  "https://en.wikipedia.org/wiki/Pakistan_Armed_Forces"
pak_URL7 =  "https://en.wikipedia.org/wiki/Pakistan"
pak_URL8 =  "https://en.wikipedia.org/wiki/National_symbols_of_Pakistan"
pak_URL9 =  "https://startuppakistan.com.pk/top-10-most-famous-people-in-pakistan/"
pak_URL10 =  "https://www.geo.tv/latest/402414-pm-imran-khan-launches-interest-free-loans-under-kamyab-pakistan-programme"
URLl_pak.append(pak_URL1)
URLl_pak.append(pak_URL2)
URLl_pak.append(pak_URL3)
URLl_pak.append(pak_URL4)
URLl_pak.append(pak_URL5)
URLl_pak.append(pak_URL6)
URLl_pak.append(pak_URL7)
URLl_pak.append(pak_URL8)
URLl_pak.append(pak_URL9)
URLl_pak.append(pak_URL10)

# URLS FOR INDIA CULTURE [CULTURE AND RELIGION]
india_URL1 = "https://www.britannica.com/place/India"
india_URL2 = r"https://en.wikipedia.org/wiki/Culture_of_India#:~:text=Indian%20culture%20is%20the%20heritage,ethno%2Dlinguistically%20diverse%20Indian%20subcontinent."
india_URL3  = "https://en.wikipedia.org/wiki/Culture_of_India#Cuisine"
india_URL4  = "https://en.wikipedia.org/wiki/Culture_of_India#Clothing"
india_URL5 =  "https://en.wikipedia.org/wiki/Culture_of_India#Wedding_rituals"
india_URL6 =  "https://en.wikipedia.org/wiki/Culture_of_India#Performing_arts"
india_URL7 =  "https://en.wikipedia.org/wiki/Culture_of_India#Perceptions_of_Indian_culture"
india_URL8 =  "https://en.wikipedia.org/wiki/Culture_of_India#Popular_media"
india_URL9 =  "https://www.britannica.com/topic/Indian-National-Congress"
india_URL0 =  r"https://en.wikipedia.org/wiki/Sport_in_India#:~:text=Other%20popular%20sports%20in%20India,polo%2C%20snooker%2C%20and%20gillidanda."
URLl_india.append(india_URL1)
URLl_india.append(india_URL2)
URLl_india.append(india_URL3)
URLl_india.append(india_URL4)
URLl_india.append(india_URL5)
URLl_india.append(india_URL6)
URLl_india.append(india_URL7)
URLl_india.append(india_URL8)
URLl_india.append(india_URL9)
URLl_india.append(india_URL0)


# APPENDING ALL CULTURE AND RELIGIONS URLs TO ONE LIST
URL_CultReligion.append(URLl_Islam)
URL_CultReligion.append(URLl_chris)
URL_CultReligion.append(URLl_Hinduism)
URL_CultReligion.append(URLl_Judaism)
URL_CultReligion.append(URLl_festivals)
URL_CultReligion.append(URLl_sikhism)
URL_CultReligion.append(URLl_pak)
URL_CultReligion.append(URLl_india)

URL_Health=[]

# URLS FOR HEALTH
health_URL1 = r"https://www.medicalnewstoday.com/articles/150999"
health_URL2 = r"https://www.physio-pedia.com/What_is_Health%3F"
health_URL3  = r"https://cherryfamilychiropractic.com/blog/why-is-health-so-important"
health_URL4  = r"https://www.balancedwellbeinghealthcare.com/five-main-factors-for-maintaining-good-health/"
health_URL5 =  r"https://www.bcu.ac.uk/health-sciences/about-us/school-blog/why-is-public-health-important"
health_URL6 =  r"https://www.toppr.com/guides/biology/why-do-we-fall-ill/health-and-its-significance/"
health_URL7 =  r"https://health.ucsd.edu/news/features/pages/2016-01-05-36-pregnancy-tips-listicle.aspx"
health_URL8 =  r"https://myhealth.alberta.ca/Health/aftercareinformation/pages/conditions.aspx?hwid=zy1780"
health_URL9 =  r"https://www.livescience.com/45090-pregnancy-diet.html"
health_URL10 =  r"https://www.stjohnhealth.com.au/blog/medical/the-importance-of-womens-health/"
health_URL11 =  r"https://www.healthline.com/health/pilomatricoma"
health_URL12 =  r"https://www.stjohnhealth.com.au/blog/medical/the-importance-of-mens-health/#:~:text=It's%20important%20that%20men%20make,they%20do%20come%20for%20help."
health_URL13 =  r"https://my.clevelandclinic.org/health/articles/16422-mens-health-lifestyle-tips-for-men-over-age-50"
health_URL14 =  r"https://connecthealth.org.au/enews/4-ways-to-improve-men-s-mental-health/"
health_URL15 =  r"https://www.nhs.uk/mental-health/self-help/guides-tools-and-activities/five-steps-to-mental-wellbeing/"
health_URL16 =  r"https://www.humanium.org/en/fundamental-rights-2/health/"
health_URL17 =  r"https://www.mhanational.org/what-every-child-needs-good-mental-health"
health_URL18 =  r"https://www.childrenscolorado.org/conditions-and-advice/parenting/parenting-articles/what-children-need/"
health_URL19 =  r"https://www.gohealthuc.com/library/five-common-infections-kids-pick-school"
health_URL20 =  r"https://my.clevelandclinic.org/health/diseases/21214-coronavirus-covid-19"
health_URL21 =  r"https://www.hopkinsmedicine.org/health/conditions-and-diseases/coronavirus"
health_URL22 =  r"https://en.wikipedia.org/wiki/Severe_acute_respiratory_syndrome_coronavirus_2#:~:text=The%20first%20known%20infections%20from,after%20the%20spillover%20event."
health_URL23 =  r"https://www.who.int/campaigns/connecting-the-world-to-combat-coronavirus/healthyathome/healthyathome---mental-health?gclid=CjwKCAjw8sCRBhA6EiwA6_IF4ViEHO0HjyNCj2sRlu0cl_t-sn9r6ysagYgn5A9I4TBi49VENzGwdxoCZrcQAvD_BwE"
health_URL24 =  r"https://en.wikipedia.org/wiki/COVID-19"
health_URL25 =  r"https://blogs.worldbank.org/endpovertyinsouthasia/covid-19-spurs-big-changes-pakistans-education"
health_URL26 =  r"https://isqua.org/blog/covid-19/covid-19-blogs/covid-19-commentary-from-india-lockdown-saga.html"
health_URL27 =  r"https://www.mayoclinic.org/diseases-conditions/coronavirus/in-depth/pregnancy-and-covid-19/art-20482639"
health_URL28 =  r"https://www.cdc.gov/coronavirus/2019-ncov/need-extra-precautions/pregnant-people.html"
health_URL29 =  r"https://www.worldbank.org/en/news/feature/2021/06/08/the-global-economy-on-track-for-strong-but-uneven-growth-as-covid-19-still-weighs"
health_URL30 =  r"https://covid19.trackvaccines.org/types-of-vaccines/#:~:text=There%20are%20two%20categories%20of,Vaccines%20and%20Whole%20Virus%20Vaccines."
health_URL31 =  r"https://www.health.harvard.edu/blog/important-health-problems-matter-2016091510267"
health_URL32 =  r"https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1448258/"
health_URL33 =  r"https://www.meenawrites.com/health-and-wellness-blog-strategies/"
health_URL33 =  r"https://www.health.harvard.edu/blog/the-mental-health-crisis-among-children-and-teens-how-parents-can-help-202203082700"
health_URL34 =  r"https://www.health.harvard.edu/blog/anti-inflammatory-food-superstars-for-every-season-202111302648"
health_URL35 =  r"https://www.health.harvard.edu/nutrition/the-10-rules-of-a-heart-healthy-diet"
health_URL36 =  r"https://www.wakeforestpediatrics.com/common-childhood-illnesses/"
health_URL37 =  r"https://www.onhealth.com/content/1/childhood_illness_sick_kids"
health_URL38 =  r"https://khealth.com/learn/pediatrics/illness-guide/"
health_URL39=  r"https://www.nct.org.uk/baby-toddler/your-babys-health/common-illnesses/childhood-illnesses-six-tips-for-how-prevent-them"
health_URL40 =  r"https://www.healthychildren.org/English/health-issues/conditions/prevention/Pages/Prevention-In-Child-Care-or-School.aspx"
health_URL41 =  r"https://www.nm.org/healthbeat/healthy-tips/9-health-issues-every-woman-should-understand"
health_URL42 =  r"https://www.who.int/news-room/commentaries/detail/ten-top-issues-for-women's-health"
health_URL43 =  r"https://www.everydayhealth.com/womens-health-photos/womens-health-threats.aspx"
health_URL44 =  r"https://www.fda.gov/consumers/consumer-updates/tips-women-prevent-heart-disease"
health_URL45 =  r"https://www.healthline.com/health/breast-cancer#inflammatory-breast-cancer"
health_URL46 =  r"https://en.wikipedia.org/wiki/Disease#:~:text=There%20are%20four%20main%20types,communicable%20versus%20non%2Dcommunicable%20diseases."
health_URL47 =  r"https://blog.mission-health.org/2021/06/16/8-common-mens-health-issues-to-watch-out-for/"
health_URL48 =  r"https://www.drugwatch.com/health/men/"
health_URL49 =  r"https://my.clevelandclinic.org/health/articles/17488-smoking"
health_URL50 =  r"https://www.theguardian.com/lifeandstyle/2018/sep/12/how-to-stay-fit-for-ever-25-tips-keep-exercising-expert-advice"


URL_Health.append(health_URL1)
URL_Health.append(health_URL2)
URL_Health.append(health_URL3)
URL_Health.append(health_URL4)
URL_Health.append(health_URL5)
URL_Health.append(health_URL6)
URL_Health.append(health_URL7)
URL_Health.append(health_URL8)
URL_Health.append(health_URL9)
URL_Health.append(health_URL10)
URL_Health.append(health_URL11)
URL_Health.append(health_URL12)
URL_Health.append(health_URL13)
URL_Health.append(health_URL14)
URL_Health.append(health_URL15)
URL_Health.append(health_URL16)
URL_Health.append(health_URL17)
URL_Health.append(health_URL18)
URL_Health.append(health_URL19)
URL_Health.append(health_URL20)
URL_Health.append(health_URL21)
URL_Health.append(health_URL22)
URL_Health.append(health_URL23)
URL_Health.append(health_URL24)
URL_Health.append(health_URL25)
URL_Health.append(health_URL26)
URL_Health.append(health_URL27)
URL_Health.append(health_URL28)
URL_Health.append(health_URL29)
URL_Health.append(health_URL30)
URL_Health.append(health_URL31)
URL_Health.append(health_URL32)
URL_Health.append(health_URL33)
URL_Health.append(health_URL34)
URL_Health.append(health_URL35)
URL_Health.append(health_URL36)
URL_Health.append(health_URL37)
URL_Health.append(health_URL38)
URL_Health.append(health_URL39)
URL_Health.append(health_URL40)
URL_Health.append(health_URL41)
URL_Health.append(health_URL42)
URL_Health.append(health_URL43)
URL_Health.append(health_URL44)
URL_Health.append(health_URL45)
URL_Health.append(health_URL46)
URL_Health.append(health_URL47)
URL_Health.append(health_URL48)
URL_Health.append(health_URL49)
URL_Health.append(health_URL50)

URL_Profession=[]

# URLS FOR PROFESSION
prof_URL1 = r"https://www.medicalnewstoday.com/articles/150999"
prof_URL2 = r"https://corporatefinanceinstitute.com/resources/knowledge/other/professional/"
prof_URL3  = r"https://harappa.education/harappa-diaries/what-is-an-occupation/"
prof_URL4  = r"https://7esl.com/jobs-and-occupations-vocabulary/"
prof_URL5 =  r"https://harappa.education/harappa-diaries/difference-between-job-and-profession/#:~:text=A%20profession%20is%20wider%20in,qualifications%20and%20experience%20to%20practice."
prof_URL6 =  r"https://marketbusinessnews.com/financial-glossary/job-definition-meaning/"
prof_URL7 =  r"https://tallo.com/blog/types-of-careers/"
prof_URL8 =  r"https://www.amtec.us.com/blog/4-types-of-jobs-thinkers-builders-improvers-and-producers"
prof_URL9 =  r"https://www.pewresearch.org/social-trends/2016/10/06/3-how-americans-view-their-jobs/"
prof_URL10 =  r"https://hbswk.hbs.edu/item/where-do-workers-go-when-robots-arrive"
prof_URL11 =  r"https://www.webmd.com/health-insurance/insurance-doctor-types"
prof_URL12 =  r"https://step.pgc.edu/top-medical-fields-pakistan/"
prof_URL13 =  r"https://my.clevelandclinic.org/health/articles/16422-mens-health-lifestyle-tips-for-men-over-age-50"
prof_URL14 =  r"https://connecthealth.org.au/enews/4-ways-to-improve-men-s-mental-health/"
prof_URL15 =  r"https://www.nhs.uk/mental-health/self-help/guides-tools-and-activities/five-steps-to-mental-wellbeing/"
prof_URL16 =  r"https://www.humanium.org/en/fundamental-rights-2/health/"
prof_URL17 =  r"https://www.mhanational.org/what-every-child-needs-good-mental-health"
prof_URL18 =  r"https://www.childrenscolorado.org/conditions-and-advice/parenting/parenting-articles/what-children-need/"
prof_URL19 =  r"https://www.gohealthuc.com/library/five-common-infections-kids-pick-school"
prof_URL20 =  r"https://my.clevelandclinic.org/health/diseases/21214-coronavirus-covid-19"
prof_URL21 =  r"https://www.hopkinsmedicine.org/health/conditions-and-diseases/coronavirus"
prof_URL22 =  r"https://en.wikipedia.org/wiki/Severe_acute_respiratory_syndrome_coronavirus_2#:~:text=The%20first%20known%20infections%20from,after%20the%20spillover%20event."
prof_URL23 =  r"https://www.who.int/campaigns/connecting-the-world-to-combat-coronavirus/healthyathome/healthyathome---mental-health?gclid=CjwKCAjw8sCRBhA6EiwA6_IF4ViEHO0HjyNCj2sRlu0cl_t-sn9r6ysagYgn5A9I4TBi49VENzGwdxoCZrcQAvD_BwE"
prof_URL24 =  r"https://en.wikipedia.org/wiki/COVID-19"
prof_URL25 =  r"https://blogs.worldbank.org/endpovertyinsouthasia/covid-19-spurs-big-changes-pakistans-education"
prof_URL26 =  r"https://isqua.org/blog/covid-19/covid-19-blogs/covid-19-commentary-from-india-lockdown-saga.html"
prof_URL27 =  r"https://www.mayoclinic.org/diseases-conditions/coronavirus/in-depth/pregnancy-and-covid-19/art-20482639"
prof_URL28 =  r"https://www.cdc.gov/coronavirus/2019-ncov/need-extra-precautions/pregnant-people.html"
prof_URL29 =  r"https://www.worldbank.org/en/news/feature/2021/06/08/the-global-economy-on-track-for-strong-but-uneven-growth-as-covid-19-still-weighs"
prof_URL30 =  r"https://covid19.trackvaccines.org/types-of-vaccines/#:~:text=There%20are%20two%20categories%20of,Vaccines%20and%20Whole%20Virus%20Vaccines."
prof_URL31 =  r"https://www.health.harvard.edu/blog/important-health-problems-matter-2016091510267"
prof_URL32 =  r"https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1448258/"
prof_URL33 =  r"https://www.meenawrites.com/health-and-wellness-blog-strategies/"
prof_URL33 =  r"https://www.health.harvard.edu/blog/the-mental-health-crisis-among-children-and-teens-how-parents-can-help-202203082700"
prof_URL34 =  r"https://www.health.harvard.edu/blog/anti-inflammatory-food-superstars-for-every-season-202111302648"
prof_URL35 =  r"https://www.health.harvard.edu/nutrition/the-10-rules-of-a-heart-healthy-diet"
prof_URL36 =  r"https://www.wakeforestpediatrics.com/common-childhood-illnesses/"
prof_URL37 =  r"https://www.onhealth.com/content/1/childhood_illness_sick_kids"
prof_URL38 =  r"https://khealth.com/learn/pediatrics/illness-guide/"
prof_URL39=  r"https://www.nct.org.uk/baby-toddler/your-babys-health/common-illnesses/childhood-illnesses-six-tips-for-how-prevent-them"
prof_URL40 =  r"https://www.healthychildren.org/English/health-issues/conditions/prevention/Pages/Prevention-In-Child-Care-or-School.aspx"
prof_URL41 =  r"https://www.nm.org/healthbeat/healthy-tips/9-health-issues-every-woman-should-understand"
prof_URL42 =  r"https://www.who.int/news-room/commentaries/detail/ten-top-issues-for-women's-health"
prof_URL43 =  r"https://www.everydayhealth.com/womens-health-photos/womens-health-threats.aspx"
prof_URL44 =  r"https://www.fda.gov/consumers/consumer-updates/tips-women-prevent-heart-disease"
prof_URL45 =  r"https://www.healthline.com/health/breast-cancer#inflammatory-breast-cancer"
prof_URL46 =  r"https://en.wikipedia.org/wiki/Disease#:~:text=There%20are%20four%20main%20types,communicable%20versus%20non%2Dcommunicable%20diseases."
prof_URL47 =  r"https://blog.mission-health.org/2021/06/16/8-common-mens-health-issues-to-watch-out-for/"
prof_URL48 =  r"https://www.drugwatch.com/health/men/"
prof_URL49 =  r"https://my.clevelandclinic.org/health/articles/17488-smoking"
prof_URL50 =  r"https://www.theguardian.com/lifeandstyle/2018/sep/12/how-to-stay-fit-for-ever-25-tips-keep-exercising-expert-advice"

URL_Profession.append(prof_URL1)
URL_Profession.append(prof_URL2)
URL_Profession.append(prof_URL3)
URL_Profession.append(prof_URL4)
URL_Profession.append(prof_URL5)
URL_Profession.append(prof_URL6)
URL_Profession.append(prof_URL7)
URL_Profession.append(prof_URL8)
URL_Profession.append(prof_URL9)
URL_Profession.append(prof_URL10)
URL_Profession.append(prof_URL11)
URL_Profession.append(prof_URL12)
URL_Profession.append(prof_URL13)
URL_Profession.append(prof_URL14)
URL_Profession.append(prof_URL15)
URL_Profession.append(prof_URL16)
URL_Profession.append(prof_URL17)
URL_Profession.append(prof_URL18)
URL_Profession.append(prof_URL19)
URL_Profession.append(prof_URL20)
URL_Profession.append(prof_URL21)
URL_Profession.append(prof_URL22)
URL_Profession.append(prof_URL23)
URL_Profession.append(prof_URL24)
URL_Profession.append(prof_URL25)
URL_Profession.append(prof_URL26)
URL_Profession.append(prof_URL27)
URL_Profession.append(prof_URL28)
URL_Profession.append(prof_URL29)
URL_Profession.append(prof_URL30)
URL_Profession.append(prof_URL31)
URL_Profession.append(prof_URL32)
URL_Profession.append(prof_URL33)
URL_Profession.append(prof_URL34)
URL_Profession.append(prof_URL35)
URL_Profession.append(prof_URL36)
URL_Profession.append(prof_URL37)
URL_Profession.append(prof_URL38)
URL_Profession.append(prof_URL39)
URL_Profession.append(prof_URL40)
URL_Profession.append(prof_URL41)
URL_Profession.append(prof_URL42)
URL_Profession.append(prof_URL43)
URL_Profession.append(prof_URL44)
URL_Profession.append(prof_URL45)
URL_Profession.append(prof_URL46)
URL_Profession.append(prof_URL47)
URL_Profession.append(prof_URL48)
URL_Profession.append(prof_URL49)
URL_Profession.append(prof_URL50)
